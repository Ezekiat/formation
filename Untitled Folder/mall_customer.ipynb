# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('../Mall_Customers.csv')

# %%
df
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler,LabelEncoder
encoder = LabelEncoder()

# %%
df['Genre'] = encoder.fit_transform(df['Genre'])

# %%
df['Income'] = df['Annual Income (k$)']
df
# Out:
#      CustomerID  Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1      1   19                  15                      39
# 1             2      1   21                  15                      81
# 2             3      0   20                  16                       6
# 3             4      0   23                  16                      77
# 4             5      0   31                  17                      40
# ..          ...    ...  ...                 ...                     ...
# 195         196      0   35                 120                      79
# 196         197      0   45                 126                      28
# 197         198      1   32                 126                      74
# 198         199      1   32                 137                      18
# 199         200      1   30                 137                      83
#
#      cluster  Income
# 0          2      15
# 1          2      15
# 2          2      16
# ...

# %%
scaler = StandardScaler()
X_scaler = scaler.fit_transform(df[['Age','Income']])

# %%
kmeans = KMeans(n_clusters=3,random_state=42)
df['cluster']= kmeans.fit_predict(X_scaler)
df
# Out:
# C:\Users\Apprenant_EDC_26\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
#      CustomerID  Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1      1   19                  15                      39
# 1             2      1   21                  15                      81
# 2             3      0   20                  16                       6
# 3             4      0   23                  16                      77
# 4             5      0   31                  17                      40
# ..          ...    ...  ...                 ...                     ...
# 195         196      0   35                 120                      79
# 196         197      0   45                 126                      28
# ...

# %%
df.head(50)
# Out:
#     CustomerID  Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0            1      1   19                  15                      39
# 1            2      1   21                  15                      81
# 2            3      0   20                  16                       6
# 3            4      0   23                  16                      77
# 4            5      0   31                  17                      40
# 5            6      0   22                  17                      76
# 6            7      0   35                  18                       6
# 7            8      0   23                  18                      94
# 8            9      1   64                  19                       3
# 9           10      0   30                  19                      72
# 10          11      1   67                  19                      14
# 11          12      0   35                  19                      99
# ...

# %%
import seaborn as sns

# %%
sns.scatterplot(data=df, x='Income', y='Age', hue='cluster', palette='Set2')
plt.title("Clustering des clients")
plt.xlabel("Annual Income (k$)")
plt.ylabel("Age")
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import silhouette_score
score = silhouette_score()
