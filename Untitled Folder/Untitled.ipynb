# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_excel('../emdat-country-profiles_pry_2025_07_16.xlsx')

# %%
df
# Out:
#                Year         Country             ISO Disaster Group  \
# 0   #date +occurred  #country +name  #country +code  #cause +group
# 1              2000        Paraguay             PRY        Natural
# 2              2002        Paraguay             PRY        Natural
# 3              2002        Paraguay             PRY        Natural
# 4              2004        Paraguay             PRY        Natural
# 5              2005        Paraguay             PRY        Natural
# 6              2007        Paraguay             PRY        Natural
# 7              2008        Paraguay             PRY        Natural
# 8              2008        Paraguay             PRY        Natural
# 9              2009        Paraguay             PRY        Natural
# 10             2009        Paraguay             PRY        Natural
# 11             2009        Paraguay             PRY        Natural
# 12             2010        Paraguay             PRY        Natural
# ...

# %%
df = df['Year',]
